# %% [markdown]
# <a href="https://colab.research.google.com/github/Caiooliveirabarreto/Aulas_PA/blob/main/Exercicios_PA_Lista01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
cotacao_dolar = float(input("digite a cotação do dolár "))
valor_em_real = float(input("digite o valor em real: "))
valor_convertido = valor_em_real/cotacao_dolar
print("seu valor em dolár: ", valor_convertido)
# Out:
# digite a cotação do dolár 3
# digite o valor em real: 50
# seu valor em dolár:  16.666666666666668

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
numero1 = float(input("digite um número: "))
numero2 = float(input("digite um número: "))
numero3 = float(input("digite um número: "))
numero4 = float(input("digite um número: "))
quadrado_numero1 = numero1 * numero1
quadrado_numero2 = numero2 * numero2
quadrado_numero3 = numero3 * numero3
quadrado_numero4 = numero4 * numero4
print(quadrado_numero1 + quadrado_numero2 + quadrado_numero3 + quadrado_numero4)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
preco_peca = float(input("digite o preço da peça: "))
qntd_vendida = float(input("digite as vendas dessa peça: "))
porcentagem_comissao = float(input("digite a comissão do vendedor(em decimais): "))
ganhos = preco_peca * qntd_vendida
comissao_vendedor = ganhos * porcentagem_comissao
print(comissao_vendedor)
# Out:
# digite o preço da peça: 10
# digite as vendas dessa peça: 150
# digite a comissão do vendedor(em decimais): 0.05
# 75.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
